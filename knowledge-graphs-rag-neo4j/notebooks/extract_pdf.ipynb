# %%
# importing required modules
from PyPDF2 import PdfReader

# creating a pdf reader object
reader = PdfReader('./data/indian_budget_speech_2024.pdf')

# printing number of pages in pdf file
#print(len(reader.pages))

pages = reader.pages
i=1
for page in pages:
# getting a specific page from the pdf file
    print("\n==========\n")
    print('Page:',i)
    print("\n==========\n")
    i = i+1
    # extracting text from page
    text = page.extract_text()[:20]
    print(text)
# Out:
# ==========
#
# Page: 1
#
# ==========
#
# GOVERNMENT OF INDIA
#
#
# ==========
#
# Page: 2
#
# ==========
#
#
#
# ==========
#
# Page: 3
#
# ==========
#
#
# CONTENTS
#
# PART
#
# ==========
#
# Page: 4
#
# ==========
#
#
#
# ==========
#
# Page: 5
#
# ==========
#
#
#
# Budget 2024 -202
#
# ==========
#
# Page: 6
#
# ==========
#
#  2
#
# Interim Budge
#
# ==========
#
# Page: 7
#
# ==========
#
#  3
#
# 8) Innovation
#
# ==========
#
# Page: 8
#
# ==========
#
#  4
#
# Vegetable pro
#
# ==========
#
# Page: 9
#
# ==========
#
#  5
#
# Scheme A: Fir
#
# ==========
#
# Page: 10
#
# ==========
#
#  6
#
# aligned to th
#
# ==========
#
# Page: 11
#
# ==========
#
#  7
#
# human resourc
#
# ==========
#
# Page: 12
#
# ==========
#
#  8
#
# 36. Grants fo
#
# ==========
#
# Page: 13
#
# ==========
#
#  9
#
# Credit Guaran
#
# ==========
#
# Page: 14
#
# ==========
#
#  10
#
# companies on
#
# ==========
#
# Page: 15
#
# ==========
#
#  11
#
# cities, in p
#
# ==========
#
# Page: 16
#
# ==========
#
#  12
#
# consistency,
#
# ==========
#
# Page: 17
#
# ==========
#
#  13
#
# Transit Orie
#
# ==========
#
# Page: 18
#
# ==========
#
#  14
#
# Priority 6:
#
# ==========
#
# Page: 19
#
# ==========
#
#  15
#
# advanced met
#
# ==========
#
# Page: 20
#
# ==========
#
#  16
#
# Pradhan Mant
#
# ==========
#
# Page: 21
#
# ==========
#
#  17
#
# Vishnupad Te
#
# ==========
#
# Page: 22
#
# ==========
#
#  18
#
# namely land,
#
# ==========
#
# Page: 23
#
# ==========
#
#  19
#
# market, skil
#
# ==========
#
# Page: 24
#
# ==========
#
#  20
#
# Use of Techn
#
# ==========
#
# Page: 25
#
# ==========
#
#  21
#
# 113. The gro
#
# ==========
#
# Page: 26
#
# ==========
#
#  22
#
# PART B
# Indi
#
# ==========
#
# Page: 27
#
# ==========
#
#  23
#
# Critical Min
#
# ==========
#
# Page: 28
#
# ==========
#
#  24
#
# 127. Further
#
# ==========
#
# Page: 29
#
# ==========
#
#  25
#
# Direct Taxes
#
# ==========
#
# Page: 30
#
# ==========
#
#  26
#
# Simplificati
#
# ==========
#
# Page: 31
#
# ==========
#
#  27
#
# 148. To disp
#
# ==========
#
# Page: 32
#
# ==========
#
#  28
#
# Deepening th
#
# ==========
#
# Page: 33
#
# ==========
#
#  29
#
# 162. Second,
#
# ==========
#
# Page: 34
#
# ==========
#
#  30
#
#
#
# ==========
#
# Page: 35
#
# ==========
#
#  31
#
# Annexure to
#
# ==========
#
# Page: 36
#
# ==========
#
#  32
#
# • Applicable
#
# ==========
#
# Page: 37
#
# ==========
#
#  33
#
# • Employee m
#
# ==========
#
# Page: 38
#
# ==========
#
#  34
#
# • New Centra
#
# ==========
#
# Page: 39
#
# ==========
#
#  35
#
# • Applicatio
#
# ==========
#
# Page: 40
#
# ==========
#
#  36
#
# Annexure to
#
# ==========
#
# Page: 41
#
# ==========
#
#  37
#
# A.3     Amen
#
# ==========
#
# Page: 42
#
# ==========
#
#  38
#
# which is fil
#
# ==========
#
# Page: 43
#
# ==========
#
#  39
#
# years 2017 -
#
# ==========
#
# Page: 44
#
# ==========
#
#  40
#
# B11.  Amendm
#
# ==========
#
# Page: 45
#
# ==========
#
#  41
#
# B17. Amendme
#
# ==========
#
# Page: 46
#
# ==========
#
#  42
#
# C.2    Amend
#
# ==========
#
# Page: 47
#
# ==========
#
#  43
#
# S.
# No. Comm
#
# ==========
#
# Page: 48
#
# ==========
#
#  44
#
# S.
# No. Comm
#
# ==========
#
# Page: 49
#
# ==========
#
#  45
#
# S.
# No. Comm
#
# ==========
#
# Page: 50
#
# ==========
#
#  46
#
# S.
# No. Comm
#
# ==========
#
# Page: 51
#
# ==========
#
#  47
#
# S.
# No. Comm
#
# ==========
#
# Page: 52
#
# ==========
#
#  48
#
# D.3. Increas
#
# ==========
#
# Page: 53
#
# ==========
#
#  49
#
# E.2.  Increa
#
# ==========
#
# Page: 54
#
# ==========
#
#  50
#
# Annexure to
#
# ==========
#
# Page: 55
#
# ==========
#
#  51
#
# • It is furt
#
# ==========
#
# Page: 56
#
# ==========
#
#  52
#
# C.2 Reducing
#
# ==========
#
# Page: 57
#
# ==========
#
#  53
#
# C.5    Ratio
#
# ==========
#
# Page: 58
#
# ==========
#
#  54
#
# C.8 Alignmen
#
# ==========
#
# Page: 59
#
# ==========
#
#  55
#
# D.6 TCS on n
#
# ==========
#
# Page: 60
#
# ==========
#
#  56
#
# (E) Tax Admi
#
# ==========
#
# Page: 61
#
# ==========
#
#  57
#
# year in whic
#
# ==========
#
# Page: 62
#
# ==========
#
#  58
#
# E.20  Removi

# %%
with open('./data/indian_budget_speech_2024.txt', 'w') as f2:
    for page in pages:
    # writing the contents of file1 into file2
        text = page.extract_text()
        f2.write(text)
